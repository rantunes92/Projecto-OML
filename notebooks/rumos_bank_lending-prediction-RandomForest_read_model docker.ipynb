# %% [markdown]
# Neste notebook vamos ler o modelo escolhido da Random Florest

# %%
import mlflow
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import joblib
import mlflow.sklearn

# %% [markdown]
# Definir a directoria onde as experiencias são guardadas

# %%
from pathlib import Path

uri = "http://127.0.0.1:5000"



mlflow.set_tracking_uri(uri)

# %%
# Fazer load da versão do modelo "Random_Forest" que registamos no notebook anterior
# Têm de mudar a versão de acordo com quantas versões registaram.

model_name = "Random_Forest"
model_version = "11"
f"models:/{model_name}/{model_version}"
# Out:
# 'models:/Random_Forest/11'

# %%
model = mlflow.sklearn.load_model(f"models:/{model_name}/{model_version}")
model
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'n_estimators': [10, 100, 300, 1000]})

# %% [markdown]
# Vamos usar o modelo para fazer previsões

# %%
data_path = '../data/rumos_bank_test.csv'
df = pd.read_csv(data_path)

# %%
nsamples=10
input_data = df.loc[df['default.payment.next.month'] == 1].sample(nsamples)
input_data
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 2043    50000.0    2          3         1   28      0      0      2      0
# 5236   220000.0    2          1         2   27     -1     -1     -1     -1
# 3854   210000.0    1          2         1   30      0      0      0      0
# 5994    50000.0    1          5         1   45      2      0      0      0
# 3121   300000.0    1          1         2   34      1     -2     -2     -2
# 4030   280000.0    1          1         1   45     -1     -1     -1     -1
# 215    150000.0    2          1         2   26      2      2      2      2
# 2152    50000.0    2          2         2   28      0      0      0      0
# 4576    30000.0    1          2         1   39      2      0      0      0
# 4268    30000.0    1          1         2   26      4      3      2      0
#
#       PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 2043      0  ...    19310.0    19848.0    20367.0    4300.0    1000.0
# ...

# %%
input = input_data.drop("default.payment.next.month", axis=1)
colunas=input.columns
input
# Out:
#       LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 2043    50000.0    2          3         1   28      0      0      2      0
# 5236   220000.0    2          1         2   27     -1     -1     -1     -1
# 3854   210000.0    1          2         1   30      0      0      0      0
# 5994    50000.0    1          5         1   45      2      0      0      0
# 3121   300000.0    1          1         2   34      1     -2     -2     -2
# 4030   280000.0    1          1         1   45     -1     -1     -1     -1
# 215    150000.0    2          1         2   26      2      2      2      2
# 2152    50000.0    2          2         2   28      0      0      0      0
# 4576    30000.0    1          2         1   39      2      0      0      0
# 4268    30000.0    1          1         2   26      4      3      2      0
#
#       PAY_5  ...  BILL_AMT3  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# ...

# %%
scaler = MinMaxScaler()
scaler = joblib.load("scaler.pkl")
input = scaler.transform(input)
input=pd.DataFrame(input, columns = colunas)

# %%
input.dtypes
# Out:
# LIMIT_BAL    float64
# SEX          float64
# EDUCATION    float64
# MARRIAGE     float64
# AGE          float64
# PAY_0        float64
# PAY_2        float64
# PAY_3        float64
# PAY_4        float64
# PAY_5        float64
# PAY_6        float64
# BILL_AMT1    float64
# BILL_AMT2    float64
# BILL_AMT3    float64
# BILL_AMT4    float64
# BILL_AMT5    float64
# BILL_AMT6    float64
# PAY_AMT1     float64
# PAY_AMT2     float64
# PAY_AMT3     float64
# PAY_AMT4     float64
# PAY_AMT5     float64
# PAY_AMT6     float64
# dtype: object

# %%
print(model)
# Out:
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              param_grid={'n_estimators': [10, 100, 300, 1000]})

# %%
print(input.dtypes)
print(input.head())
# Out:
# LIMIT_BAL    float64
# SEX          float64
# EDUCATION    float64
# MARRIAGE     float64
# AGE          float64
# PAY_0        float64
# PAY_2        float64
# PAY_3        float64
# PAY_4        float64
# PAY_5        float64
# PAY_6        float64
# BILL_AMT1    float64
# BILL_AMT2    float64
# BILL_AMT3    float64
# BILL_AMT4    float64
# BILL_AMT5    float64
# BILL_AMT6    float64
# PAY_AMT1     float64
# PAY_AMT2     float64
# PAY_AMT3     float64
# PAY_AMT4     float64
# PAY_AMT5     float64
# PAY_AMT6     float64
# dtype: object
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE       AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   0.040404  1.0   0.500000  0.333333  0.120690    0.2    0.2    0.4    0.2
# 1   0.212121  1.0   0.166667  0.666667  0.103448    0.1    0.1    0.1    0.1
# 2   0.202020  0.0   0.333333  0.333333  0.155172    0.2    0.2    0.2    0.2
# 3   0.040404  0.0   0.833333  0.333333  0.413793    0.4    0.2    0.2    0.2
# ...

# %%
#model.predict(input)
y_probs = model.predict_proba(input)[:, 1]
y_preds = (y_probs > 0.3).astype(int)
print(y_preds)
# Out:
# [1 0 0 0 1 0 1 0 1 1]

# %% [markdown]
# Obtendo os resultados previstos, podemos testar se está de acordo com a accuracy do modelo

# %%
# Obter informações do modelo registrado
client = mlflow.tracking.MlflowClient()
model_info = client.get_model_version(model_name, model_version)

# Obter o ID do run associado ao modelo
run_id = model_info.run_id

# Recuperar as métricas do modelo
metrics = client.get_run(run_id).data.metrics
accuracy=metrics.get("accuracy")


# Mostrar a accuracy
print("Accuracy do modelo:", accuracy )
# Out:
# Accuracy do modelo: 0.817

# %%
# Calcular a soma dos valores previstos que há de ser semelhante à accuracy
soma_y_preds = sum(y_preds)
soma_y_preds
# Out:
# np.int64(5)

# %%
# Teste com assert para verificar se a soma dos y_preds faz sentido em relação à accuracy
assert soma_y_preds <= len(y_preds), "Erro: Soma dos y_preds maior que o número de previsões"
assert nsamples*accuracy-5*nsamples/10 <= soma_y_preds <= nsamples*accuracy+5*nsamples/10, "Erro: Accuracy fora do intervalo esperado"


print("Testes concluídos com sucesso!")
# Out:
# Testes concluídos com sucesso!
